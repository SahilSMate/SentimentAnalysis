# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = ''
reviewlist=[]

# %%
def get_soup(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.content,'html.parser')
    return soup

# %%
def get_reviews(soup):
    reviews = soup.find_all('div',{'data-hook': 'review'})
    try: 
        for item in reviews:
            review={
            'product' : soup.title.text.replace('Amazon.in:Customer reviews:', '').strip(),
            'profile_name' : item.find('span', {'class': 'a-profile-name'}).text.strip(),
            'title' : item.find('a',{'data-hook': 'review-title'}).text.strip(),
            'rating' : float(item.find('i',{'data-hook': 'review-star-rating'}).text.replace('out of 5 stars','').strip()),
            'body' : item.find('span',{'data-hook': 'review-body'}).text.strip()
            }
            reviewlist.append(review)
    except:
        pass

# %%
for x in range(1,500):
    soup = get_soup(f'https://www.amazon.in/Havells-HD3151-Hair-Dryer-Turquoise/product-reviews/B01N33BLDT/ref=cm_cr_arp_d_paging_btm_next_500?ie=UTF8&reviewerType=all_reviews&pageNumber={x}')
    get_reviews(soup)
    print(len(reviewlist))
# Out:
# 10
# 10
# 20
# 20
# 30
# 40
# 50
# 60
# 70
# 70
# 80
# 90
# 100
# 110
# 120
# 130
# 130
# 130
# 130
# 140
# 140
# 150
# 150
# 150
# 150
# 160
# 160
# 170
# 180
# 190
# 200
# 210
# 210
# 220
# 230
# 240
# 250
# 250
# 250
# 250
# 250
# 260
# 270
# 280
# 290
# 300
# 310
# 320
# 330
# 330
# 340
# 350
# 360
# 370
# 380
# 390
# 400
# 410
# 420
# 430
# 440
# 440
# 450
# 460
# 470
# 480
# 490
# 500
# 510
# 510
# 520
# 530
# 540
# 550
# 560
# 560
# 570
# 570
# 580
# 580
# 580
# 580
# 590
# 600
# 610
# 610
# 620
# 630
# 630
# 640
# 640
# 650
# 650
# 650
# 660
# 670
# 670
# 680
# 690
# 700
# 710
# 720
# 730
# 740
# 740
# 740
# 740
# 750
# 750
# 760
# 770
# 780
# 790
# 800
# 810
# 820
# 830
# 840
# 850
# 860
# 870
# 880
# 880
# 890
# 890
# 900
# 900
# 900
# 910
# 920
# 930
# 940
# 950
# 960
# 970
# 980
# 990
# 1000
# 1010
# 1020
# 1020
# 1020
# 1030
# 1040
# 1050
# 1060
# 1070
# 1070
# 1070
# 1070
# 1070
# 1080
# 1090
# 1100
# 1110
# 1110
# 1120
# 1120
# 1130
# 1130
# 1130
# 1130
# 1130
# 1130
# ...

# %%
df = pd.DataFrame(reviewlist)

# %%
df.tail(20)
# Out:
#                                                 product         profile_name  \
# 3070  Havells HD3151 1200 W Foldable Hair Dryer; 3 H...               BANTOO
# 3071  Havells HD3151 1200 W Foldable Hair Dryer; 3 H...       ABHINABA DUTTA
# 3072  Havells HD3151 1200 W Foldable Hair Dryer; 3 H...               Sonali
# 3073  Havells HD3151 1200 W Foldable Hair Dryer; 3 H...     Kanchana V Joshi
# 3074  Havells HD3151 1200 W Foldable Hair Dryer; 3 H...                 licy
# 3075  Havells HD3151 1200 W Foldable Hair Dryer; 3 H...            Sk sawpon
# 3076  Havells HD3151 1200 W Foldable Hair Dryer; 3 H...          Danik Apang
# 3077  Havells HD3151 1200 W Foldable Hair Dryer; 3 H...  Jayanthi sureshbabu
# 3078  Havells HD3151 1200 W Foldable Hair Dryer; 3 H...            Naveed s.
# 3079  Havells HD3151 1200 W Foldable Hair Dryer; 3 H...        Sohail Qaiser
# 3080  Havells HD3151 1200 W Foldable Hair Dryer; 3 H...                Kapil
# ...

# %%
df.describe()
# Out:
#             rating
# count  3090.000000
# mean      4.133657
# std       1.292932
# min       1.000000
# 25%       4.000000
# 50%       5.000000
# 75%       5.000000
# max       5.000000

# %%
df.to_excel('havells-hairdryer-reviews-final.xlsx', index=False)

# %%
df['profile_name'].value_counts()
# Out:
# Amazon Customer    211
# Rahul                8
# Rajesh               5
# Amazon customer      4
# Surendra             4
#                   ...
# amrutahegde          1
# Shaik Imran B        1
# k k shukla           1
# madhul               1
# Sharu P.             1
# Name: profile_name, Length: 2733, dtype: int64
